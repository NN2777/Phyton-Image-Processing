# %% [markdown]
# <a href="https://colab.research.google.com/github/NN2777/Phyton-Image-Processing/blob/main/Week2_Praktikum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/koceng/koceng_garong.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/koceng/koceng_garong.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#pt1 = titik awal, pt2= titik akhir
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color= (0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(400,400), radius=1, color=(255,0,0), thickness=50)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %%
imgkucing = cv.imread('/content/drive/MyDrive/koceng/koceng_garong.jpg')
plt.imshow(imgkucing)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(imgkucing)

# %%
imgkucing2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(imgkucing2[10:100][10:100])

# %%
from random import randint
import random

for i in range(5):
  cv.rectangle(imgkucing2, pt1=(random.randint(0,600),random.randint(0,350)), pt2=(random.randint(0,600),random.randint(0,350)), color= (random.randint(0,255), random.randint(0,255), random.randint(0,255)), thickness=random.randint(0,15))

plt.imshow(imgkucing2)

# %%
imgcvt = cv.cvtColor(imgkucing2, cv.COLOR_BGR2RGB)
imgbalik = cv.flip(cv.cvtColor(imgcvt, cv.COLOR_BGR2RGB), 0)
plt.imshow(imgbalik)

# %%
#nomer 4
imgkucing3 = imgkucing
imgkucing3[:, :, 2] = 0
imgkucing3[:, :, 0] = 0
plt.imshow(imgkucing3[5:30][0:imgkucing3.shape[1]])

# %%
#nomer 2
imgkucing4 = cv.cvtColor(imgkucing, cv.COLOR_BGR2RGB)
imgkucing4[:, :, 2] = 0

imgkucing5 = cv.cvtColor(imgkucing, cv.COLOR_BGR2RGB)
imgkucing5[:, :, 0] = 0

final_frame = cv.hconcat((imgkucing4, imgkucing5))

plt.imshow(final_frame)

# %%
Naufalimg = cv.imread('/content/drive/MyDrive/koceng/Naufal.jpg')
Naufalimg = cv.cvtColor(Naufalimg, cv.COLOR_BGR2RGB)

cv.circle(Naufalimg, center = (630, 370), radius=150, color=(255,0,0), thickness=3)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(Naufalimg, text='CLOWN', org=(200,600), fontFace=font, fontScale=4, color=(255,0,0), thickness=5, lineType=cv.LINE_AA)

plt.imshow(Naufalimg)

# %%
lenaimg = cv.imread('/content/drive/MyDrive/koceng/lena.jpg')
lenaimg = cv.cvtColor(lenaimg, cv.COLOR_BGR2RGB)

rectangle = cv.rectangle(lenaimg, pt1=(0,lenaimg.shape[1]), pt2=(200,300), color=(0,0,255), thickness=5)

lenaimg[:, :, 0] = 0
lenaimg[:, :, 1] = 0

text = cv.putText(lenaimg, text='lena.jpg', org=(10,100), fontFace=font, fontScale=4, color=(255,255,0), thickness=5, lineType=cv.LINE_AA)

plt.imshow(lenaimg)
